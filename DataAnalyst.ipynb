# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  ## Adjust the configuration of the plots which we will be creating

# %% [markdown]
# ## Read in the data

# %% [markdown]
# df = pd.read_csv('movies.csv')

# %% [markdown]
# ## Let's look at the data

# %%
df
# print(df)
# df.head()
# print(df.head())
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %% [markdown]
# ## Let's see if there is any missing data

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %% [markdown]
# # Dropping all rows with any missing values

# %%
df = df.dropna(axis=0)  ## Even if I don't write axis=0,it will work as default

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %% [markdown]
# # Data types for our columns

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# # Changing votes, budget, gross and runtime columns to integer values

# %%
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# # Year in released and year column should match

# %%
## Extra: like for eg; to make a column as string datatype use,
## df['released_year'] = df['released'].astype('str').str(:4)
## We are also extracting only the first four letters and forming a new column

# %% [markdown]
# ## Extracting only year from the released column

# %%
def get_released_year(year):
    return year.split(', ')[-1].split(' ')[0]
df['released_year'] = df['released'].apply(lambda x: f"{get_released_year(x)}")
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# ## DOUBT:

# %%
# df.released_year.head()
## Not working hence I will be converting year into object type ie str in order to match them
# df['released_year'] = df['released_year'].astype('int')
df['year'] = df['year'].astype('str')
df.year.head()
# Out:
# 0    1980
# 1    1980
# 2    1980
# 3    1980
# 4    1980
# Name: year, dtype: object

# %% [markdown]
# ## Sorting based on gross value

# %%
## We can look at a particular data
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
## Didn't run
df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()

# %%
## Didn't use(we can look at all the data)
pd.set_options('display.max_rows', None)

# %% [markdown]
# ## Dropping all the duplicates

# %%
df['company'].sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 352                                      Zoetrope Studios
# 724                                      Zoetrope Studios
# 332                                      Zoetrope Studios
# 520                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 4297                              Zentropa Entertainments
# 5471                              Zentropa Entertainments
# 3698                              Zentropa Entertainments
# ...

# %%
## Distinct count of the sort values
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
df['company'] = df['company'].drop_duplicates().sort_values(ascending=False)
print(df['company'])
# Out:
# 0                                            Warner Bros.
# 1                                       Columbia Pictures
# 2                                               Lucasfilm
# 3                                      Paramount Pictures
# 4                                          Orion Pictures
# 5                                                     NaN
# 6                                      Universal Pictures
# 7                            Chartoff-Winkler Productions
# 8                                          Dovemead Films
# 9                                          United Artists
# 10                                    The Malpaso Company
# 11                                           C.A.T. Films
# 12                                                    NaN
# 13                                                    NaN
# 14                                      Filmways Pictures
# 15                                        Rastar Pictures
# ...

# %%
df = df.drop_duplicates()
print(df)
# Out:
#                                                    name     rating      genre  \
# 0                                           The Shining          R      Drama
# 1                                       The Blue Lagoon          R  Adventure
# 2        Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                             Airplane!         PG     Comedy
# 4                                            Caddyshack          R     Comedy
# 5                                       Friday the 13th          R     Horror
# 6                                    The Blues Brothers          R     Action
# 7                                           Raging Bull          R  Biography
# 8                                           Superman II         PG     Action
# 9                                       The Long Riders          R  Biography
# 10                                Any Which Way You Can         PG     Action
# ...

# %%
## budget has high correlation with the gross value
## company has high correlation with the gross value

# %% [markdown]
# ## Scatter plot between budget v/s gross

# %%
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget v/s Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Film Budget')
plt.show()

# %% [markdown]
# ## reg plot or regression plot using seaborn

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})
plt.show()
## linear plot

# %% [markdown]
# ## Let's start looking at the correlation

# %%
## Only works for numerical values
## Correlation: Pearson, Kendall, Spearman
## Pearson Correlation By Default
## year will not come as str(released year will also not come as str)
df.corr()  ## correlation matrix

# df.corr(method='pearson')  ## same as above
# df.corr(method='kendall')  ## different, not tried
# df.corr(method='spearman')  ## different, not tried

## There is actually not very high correlation between budget and gross
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# ## Heat Map Plot

# %%
correlation_matrix = df.corr(method='pearson')  ## We can change method='kendall' or 'spearman'
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
## Contains month name
df.released_year
## left work
# Out:
# 0            1980
# 1            1980
# 2            1980
# 3            1980
# 4            1980
# 5            1980
# 6            1980
# 7            1980
# 8            1981
# 9            1980
# 10           1980
# 11           1984
# 12           1980
# 13           1980
# 14           1980
# 15           1980
# 17           1980
# 18           1980
# 20           1980
# 21           1981
# 22           1980
# 23           1980
# 28           1980
# 29           1980
# 33           1981
# 35           1980
# 36           1980
# 37           1980
# 42           1980
# 46           1980
# 48           1980
# 50           1980
# 51           1980
# 53           1980
# 56           1980
# 57           1980
# 58           1980
# 75           1980
# 77           1980
# 80           1980
# 92           1981
# 94           1981
# 95           1981
# 96           1983
# 97           1982
# 98           1981
# 99           1981
# 100          1981
# 101          1982
# 103          1981
# ...

# %% [markdown]
# ## Look at the companies(converting str to int)

# %%
df_numeric = df
for col_name in df_numeric.columns:
    if(df_numeric[col_name].dtype == 'object'):
        df_numeric[col_name] = df_numeric[col_name].astype('category')
        df_numeric[col_name] = df_numeric[col_name].cat.codes  ## random numerization
df_numeric.head()
## It solely focussed on the object datatype, hence our year and released_year columns also changed
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  4692       6      6     0      1304    8.4   927000      1795    2832
# 1  3929       6      1     0      1127    5.8    65000      1578    1158
# 2  3641       4      0     0      1359    8.7  1200000       757    1818
# 3   204       4      4     0      1127    7.7   221000       889    1413
# 4   732       6      4     0      1170    7.3   108000       719     351
#
#    star  country    budget      gross  company  runtime  released_year
# 0   699       46  19000000   46998772     1426      146              0
# 1   214       47   4500000   58853106      452      104              0
# 2  1157       47  18000000  538375067      945      124              0
# 3  1474       47   3500000   83453539     1108       88              0
# 4   271       47   6000000   39846344     1083       98              0

# %%
correlation_matrix = df_numeric.corr(method='pearson')  ## We can change method='kendall' or 'spearman'
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numeric.corr().head(16)
# Out:
#                    name    rating     genre      year  released     score  \
# name           1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating        -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre          0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year           0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released      -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score          0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes          0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director       0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer         0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star          -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country       -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget         0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
correlation_mat = df_numeric.corr()
corr_pair = correlation_mat.unstack()
corr_pair
# Out:
# name           name             1.000000
#                rating          -0.029234
#                genre            0.010996
#                year             0.025542
#                released        -0.006152
#                score            0.014450
#                votes            0.012615
#                director         0.015246
#                writer           0.012880
#                star            -0.006882
#                country         -0.025490
#                budget           0.023392
#                gross            0.005639
#                company          0.011370
#                runtime          0.010850
#                released_year    0.023234
# rating         name            -0.029234
#                rating           1.000000
#                genre            0.147796
#                year             0.019499
#                released         0.018083
#                score            0.065983
#                votes            0.006031
# ...

# %%
sorted_corr_pair = corr_pair.sort_values()
sorted_corr_pair
# Out:
# genre          budget          -0.368523
# budget         genre           -0.368523
# genre          gross           -0.244101
# gross          genre           -0.244101
# budget         rating          -0.203946
# rating         budget          -0.203946
# company        budget          -0.197893
# budget         company         -0.197893
# rating         gross           -0.181906
# gross          rating          -0.181906
# company        gross           -0.147686
# gross          company         -0.147686
# votes          genre           -0.135990
# genre          votes           -0.135990
# country        company         -0.114793
# company        country         -0.114793
#                votes           -0.099914
# votes          company         -0.099914
# country        released_year   -0.074422
# released_year  country         -0.074422
# year           genre           -0.073167
# genre          year            -0.073167
# year           company         -0.068506
# ...

# %%
high_corr = sorted_corr_pair[(sorted_corr_pair) > 0.5]
high_corr
# Out:
# gross          votes            0.614751
# votes          gross            0.614751
# gross          budget           0.740247
# budget         gross            0.740247
# released_year  year             0.990417
# year           released_year    0.990417
# name           name             1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# writer         writer           1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# released_year  released_year    1.000000
# dtype: float64

# %%
## budget and votes have the highest correlation with the gross
## company has low correlation with the gross
